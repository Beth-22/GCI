# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import numpy.random as random

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# %%
file_path = "Forest_Area.csv"
# Load the latest version
data = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "kanchana1990/global-forest-insights-1990-2020-fao",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)
# Out:
# C:\Users\nate8\AppData\Local\Temp\ipykernel_96180\1546295545.py:3: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   data = kagglehub.load_dataset(

# %%
print("First 5 records:", data.head())
# Out:
# First 5 records:    CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 0        NaN            WORLD         4236433.42         4158049.52
# 1        4.0      Afghanistan            1208.44            1208.44
# 2        8.0          Albania             788.80             769.30
# 3       12.0          Algeria            1667.00            1579.00
# 4       16.0   American Samoa              18.07              17.73
#
#    Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 0         4106316.94                          4058930.81
# 1            1208.44           1208.44            1208.44
# 2             782.07            789.19             788.90
# 3            1918.00              1956            1949.00
# 4              17.43             17.28              17.13
#
#    Total Land Area, 2020  \
# 0             13003000.0
# 1                65286.0
# 2                 2740.0
# 3               238174.0
# 4                   20.0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 11 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   CountryID                                             236 non-null    float64
#  1   Country and Area                                      237 non-null    str
#  2   Forest Area, 1990                                     237 non-null    float64
#  3   Forest Area, 2000                                     237 non-null    float64
#  4   Forest Area, 2010                                     237 non-null    float64
#  5   Forest Area, 2015                                     237 non-null    str
#  6   Forest Area, 2020                                     237 non-null    float64
#  7   Total Land Area, 2020                                 237 non-null    float64
# ...

# %%
data.describe()
# Out:
#         CountryID  Forest Area, 1990  Forest Area, 2000  Forest Area, 2010  \
# count  236.000000       2.370000e+02       2.370000e+02       2.370000e+02
# mean   444.563559       3.575049e+04       3.508903e+04       3.465246e+04
# std    253.068287       2.836953e+05       2.784833e+05       2.750633e+05
# min      4.000000       0.000000e+00       0.000000e+00       0.000000e+00
# 25%    229.750000       3.361000e+01       3.370000e+01       3.452000e+01
# 50%    452.000000       1.188000e+03       1.233000e+03       1.234720e+03
# 75%    660.500000       8.769170e+03       8.369250e+03       8.468160e+03
# max    894.000000       4.236433e+06       4.158050e+06       4.106317e+06
#
#        Forest Area, 2020  Total Land Area, 2020  \
# count       2.370000e+02           2.370000e+02
# mean        3.425258e+04           1.098799e+05
# std         2.720227e+05           8.577117e+05
# min         0.000000e+00           0.000000e+00
# ...

# %%
data.head().T
# Out:
#                                                              0            1  \
# CountryID                                                  NaN          4.0
# Country and Area                                         WORLD  Afghanistan
# Forest Area, 1990                                   4236433.42      1208.44
# Forest Area, 2000                                   4158049.52      1208.44
# Forest Area, 2010                                   4106316.94      1208.44
# Forest Area, 2015
#       1208.44
# Forest Area, 2020                                   4058930.81      1208.44
# Total Land Area, 2020                               13003000.0      65286.0
# Forest Area as a Proportion of Total Land Area,...       31.13         1.85
# Deforestation, 2015-2020                                 10200          ...
# Total Forest Area Affected by Fire, 2015                 98040          ...
#
#                                                           2         3  \
# ...

# %%
data['Total Land Area, 2020']
# Out:
# 0      13003000.0
# 1         65286.0
# 2          2740.0
# 3        238174.0
# 4            20.0
#           ...
# 234       52797.0
# 235       74339.0
# 236       38685.0
# 237           NaN
# 238           NaN
# Name: Total Land Area, 2020, Length: 239, dtype: float64

# %%
data[['Total Land Area, 2020', 'Forest Area, 2020']]
# Out:
#      Total Land Area, 2020  Forest Area, 2020
# 0               13003000.0         4058930.81
# 1                  65286.0            1208.44
# 2                   2740.0             788.90
# 3                 238174.0            1949.00
# 4                     20.0              17.13
# ..                     ...                ...
# 234                52797.0             549.00
# 235                74339.0           44814.03
# 236                38685.0           17444.58
# 237                    NaN                NaN
# 238                    NaN                NaN
#
# [239 rows x 2 columns]

# %%
data[0:3]
# Out:
#    CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 0        NaN            WORLD         4236433.42         4158049.52
# 1        4.0      Afghanistan            1208.44            1208.44
# 2        8.0          Albania             788.80             769.30
#
#    Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 0         4106316.94
#          4058930.81
# 1            1208.44           1208.44            1208.44
# 2             782.07            789.19             788.90
#
#    Total Land Area, 2020  \
# 0             13003000.0
# 1                65286.0
# 2                 2740.0
#
#    Forest Area as a Proportion of Total Land Area, 2020  \
# 0                                              31.13
# 1                                               1.85
# 2                                              28.79
#
#   Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 0                    10200                                    98040
# ...

# %%
data.loc[4]
# Out:
# CountryID                                                         16.0
# Country and Area                                        American Samoa
# Forest Area, 1990                                                18.07
# Forest Area, 2000                                                17.73
# Forest Area, 2010                                                17.43
# Forest Area, 2015                                                17.28
# Forest Area, 2020                                                17.13
# Total Land Area, 2020                                             20.0
# Forest Area as a Proportion of Total Land Area, 2020             85.65
# Deforestation, 2015-2020                                           ...
# Total Forest Area Affected by Fire, 2015                             0
# Name: 4, dtype: object

# %%
data.loc[3:8]
# Out:
#    CountryID     Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 3       12.0              Algeria            1667.00            1579.00
# 4       16.0       American Samoa              18.07              17.73
# 5       20.0              Andorra              16.00              16.00
# 6       24.0               Angola           79262.78           77708.61
# 7      660.0             Anguilla               5.50               5.50
# 8       28.0  Antigua and Barbuda              10.11               9.45
#
#    Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 3            1918.00              1956            1949.00
# 4              17.43             17.28              17.13
# 5              16.00                16              16.00
# 6           72158.00          69382.69           66607.38
# 7               5.50               5.5               5.50
# 8               8.78              8.45               8.12
#
#    Total Land Area, 2020  \
# ...

# %%
data.loc[:, 'Country and Area']
# Out:
# 0               WORLD
# 1         Afghanistan
# 2             Albania
# 3             Algeria
# 4      American Samoa
#             ...
# 234             Yemen
# 235            Zambia
# 236          Zimbabwe
# 237               NaN
# 238               NaN
# Name: Country and Area, Length: 239, dtype: str

# %%
data.loc[:, ['Country and Area', 'Forest Area, 2020']]
# Out:
#     Country and Area  Forest Area, 2020
# 0              WORLD         4058930.81
# 1        Afghanistan            1208.44
# 2            Albania             788.90
# 3            Algeria            1949.00
# 4     American Samoa              17.13
# ..               ...                ...
# 234            Yemen             549.00
# 235           Zambia           44814.03
# 236         Zimbabwe           17444.58
# 237              NaN                NaN
# 238              NaN                NaN
#
# [239 rows x 2 columns]

# %%
data.iloc[0:4, [0, 2]]
# Out:
#    CountryID  Forest Area, 1990
# 0        NaN         4236433.42
# 1        4.0            1208.44
# 2        8.0             788.80
# 3       12.0            1667.00

# %%
data.at[1, 'Forest Area, 2020']
# Out:
# np.float64(1208.44)

# %%
print(data['Forest Area, 2020'] >= 1000.0)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 234    False
# 235     True
# 236     True
# 237    False
# 238    False
# Name: Forest Area, 2020, Length: 239, dtype: bool

# %%
data[(data['Country and Area']== 'Ethiopia') | (data['Country and Area']== 'Brazil' )]
# Out:
#     CountryID Country and Area  Forest Area, 1990  Forest Area, 2000  \
# 29       76.0           Brazil           588898.0           551088.6
# 68      231.0         Ethiopia            19258.5            18528.5
#
#     Forest Area, 2010 Forest Area, 2015  Forest Area, 2020  \
# 29           511580.7          503884.8           496619.6
# 68            17798.5           17433.5            17068.5
#
#     Total Land Area, 2020  \
# 29              835814.00
# 68              111971.55
#
#     Forest Area as a Proportion of Total Land Area, 2020  \
# 29                                              59.42
# 68                                              15.24
#
#    Deforestation, 2015-2020 Total Forest Area Affected by Fire, 2015
# 29                   1695.7                                 32998.07
# 68                       92                                      ...

# %%
data.isnull().sum()
# Out:
# CountryID                                               3
# Country and Area                                        2
# Forest Area, 1990                                       2
# Forest Area, 2000                                       2
# Forest Area, 2010                                       2
# Forest Area, 2015                                       2
# Forest Area, 2020                                       2
# Total Land Area, 2020                                   2
# Forest Area as a Proportion of Total Land Area, 2020    2
# Deforestation, 2015-2020                                2
# Total Forest Area Affected by Fire, 2015                2
# dtype: int64

# %%
data.sort_values(by='Forest Area, 2020', ascending=False).head()
# Out:
#      CountryID          Country and Area  Forest Area, 1990  \
# 0          NaN                     WORLD         4236433.42
# 174      643.0        Russian Federation          808949.90
# 29        76.0                    Brazil          588898.00
# 38       124.0                    Canada          348272.93
# 225      840.0  United States of America          302450.00
#
#      Forest Area, 2000  Forest Area, 2010 Forest Area, 2015  \
# 0           4158049.52         4106316.94
#
# 174          809268.50          815135.60         814930.46
# 29           551088.60          511580.70          503884.8
# 38           347801.97          347322.21         347115.71
# 225          303536.00          308720.00            310095
#
#      Forest Area, 2020  Total Land Area, 2020  \
# 0           4058930.81             13003000.0
# 174          815311.60              1637687.0
# 29           496619.60               835814.0
# 38           346928.10               909351.0
# ...
